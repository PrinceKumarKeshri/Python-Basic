# %%
pwd
# Out:
# 'C:\\Users\\0526p'

# %%
f = open('practice.txt', 'w')
f.write('This is a test string')
f.write('\nHi! I\'m Prince')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\0526p'

# %%
os.listdir()
# Out:
# [' random value is equal to guess value 1.ipynb',
#  ' random value is equal to guess value 2.ipynb',
#  ' random value is equal to guess value 3.ipynb',
#  ' random value is equal to guess value.ipynb',
#  '.anaconda',
#  '.android',
#  '.AndroidStudio3.5',
#  '.atom',
#  '.conda',
#  '.condarc',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.nbi',
#  '.packettracer',
#  '.pylint.d',
#  '.spyder-py3',
#  '.vscode',
#  '.xdm-global-lock',
#  '.xdman',
#  '3D Objects',
#  'abc.txt',
#  'aiml face mask',
#  'Anaconda3',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'args and kwargs.ipynb',
#  'Assignment 1.ipynb',
#  'assignment 2 .ipynb',
#  'Assignment 2A.ipynb',
#  'Assignment 3.ipynb',
#  'Assignment 4.ipynb',
#  'Assignment 5.ipynb',
#  'Assignment 6.ipynb',
#  'Assignment 7.ipynb',
#  'A_T_M.ipynb',
#  'calculate the average of marks 1.ipynb',
#  'calculate the average of marks.ipynb',
#  'Calen Probs.ipynb',
#  'Cisco Packet Tracer 8.0',
#  'class 1 revision.ipynb',
#  'class 1.ipynb',
#  'class work.ipynb',
#  'Collections Module.ipynb',
#  'Contacts',
#  'Cookies',
#  'count the repeat words 1.ipynb',
#  'count the repeat words.ipynb',
#  'create audio voice.ipynb',
#  'date and time.ipynb',
#  'decorators.ipynb',
#  'defining fuction 4.ipynb',
#  'defining function 1.ipynb',
#  'defining function 10.ipynb',
#  'defining function 2.ipynb',
#  'defining function 3.ipynb',
#  'defining function 5.ipynb',
#  'defining function 6.ipynb',
#  'defining function 7.ipynb',
#  'defining function 8.ipynb',
#  'defining function 9.ipynb',
#  'Desktop',
#  'dictionary.ipynb',
#  'Documents',
#  'doochi_1.ipynb',
#  'Downloads',
#  'edureka ai face mask project',
#  'edureka-ai project day 2.ipynb',
#  'Errors and Exception Handling.ipynb',
#  'Favorites',
#  'file 1.ipynb',
#  'file 2.ipynb',
#  'find average of grades.ipynb',
#  'flag.ipynb',
#  'for loop 1.ipynb',
#  'for loop 2.ipynb',
#  'For loop.ipynb',
#  'Functions and Methods Homework.ipynb',
#  'Generators.ipynb',
#  'Greatest and Equal Between Four Number.ipynb',
#  'greatest of four digit.ipynb',
#  'Greatest of four integer.ipynb',
#  'hello world.ipynb',
#  'ho-chi-tao.ipynb',
#  'if  elif else.ipynb',
#  'if elif else 1.ipynb',
#  'IntelGraphicsProfiles',
#  'intershala ml training',
#  'lam, map and filter.ipynb',
#  'Lecture 4-Copy1.ipynb',
#  'Lecture 4.ipynb',
#  'Lecture 5.ipynb',
#  'Lecture 6.ipynb',
#  'Lecture 7.ipynb',
#  'Lecture 8.ipynb',
#  'Lecture 9.ipynb',
#  'legb rule.ipynb',
#  'Lev_1.ipynb',
#  'Lev_2.ipynb',
#  'Links',
#  'list 4.ipynb',
#  'list coprehension.ipynb',
#  'list_1.ipynb',
#  'list_2.ipynb',
#  'list_3.ipynb',
#  'Local Settings',
#  'Methods and Functions.ipynb',
#  'MicrosoftEdgeBackups',
#  'ML M4 T2 V4 Data exploration target variable 4.ipynb',
#  'Modules and Packages 1.ipynb',
#  'Music',
#  'My Documents',
#  'my exa 4.ipynb',
#  'my exa 5.ipynb',
#  'myexa copy.ipynb',
#  'myexa.ipynb',
#  'myexa2.ipynb',
#  'myexa3.ipynb',
#  'myfile_text',
#  'my_file.text',
#  'my_file.txt',
#  'nes sten & sco 1.ipynb',
#  'nes sten & sco.ipynb',
#  'NetHood',
#  'newXMLDocument.xml',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TM.blf',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Overview of geoprocessing using python',
#  'Pictures',
#  'playing card game.ipynb',
#  'practice.txt',
#  'PrintHood',
#  'py.py',
#  'pyth.py',
#  'python',
#  'quiz1.ipynb',
#  'quiz2.ipynb',
#  'Recent',
#  'reverse_1.ipynb',
#  'reverse_2.ipynb',
#  'reverse_3.ipynb',
#  'revision 1.ipynb',
#  'revision 2.ipynb',
#  'revision 3.ipynb',
#  'revision 4.ipynb',
#  'revision 5.ipynb',
#  'revision 6.ipynb',
#  'revision.ipynb',
#  'rough',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'set_1.ipynb',
#  'set_2.ipynb',
#  'Shutil and OS Modules.ipynb',
#  'star pattern.ipynb',
#  'Start Menu',
#  'string formating.ipynb',
#  'Templates',
#  'testfile',
#  'text_to_speech.ipynb',
#  'Tic Tac Toe game.ipynb',
#  'time pass 1.ipynb',
#  'time pass 2.ipynb',
#  'time pass 3.ipynb',
#  'time pass 4.ipynb',
#  'ttt.ipynb',
#  'tuple.ipynb',
#  'untitled0.py',
#  'untitled1.py',
#  'user defined list.ipynb',
#  'Videos',
#  'while 1.ipynb',
#  'while 2.ipynb']

# %%
os.listdir('C:\\Users')
# Out:
# ['0526p', 'All Users', 'Default', 'Default User', 'desktop.ini', 'Public']

# %%
import shutil

# %%
shutil.move('C:\\Users\\0526p\\practice.txt', 'C:\\Users\\0526p\\rough')
# Out:
# 'C:\\Users\\0526p\\rough\\practice.txt'

# %%
os.listdir('C:\\Users\\0526p')
# Out:
# [' random value is equal to guess value 1.ipynb',
#  ' random value is equal to guess value 2.ipynb',
#  ' random value is equal to guess value 3.ipynb',
#  ' random value is equal to guess value.ipynb',
#  '.anaconda',
#  '.android',
#  '.AndroidStudio3.5',
#  '.atom',
#  '.conda',
#  '.condarc',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.nbi',
#  '.packettracer',
#  '.pylint.d',
#  '.spyder-py3',
#  '.vscode',
#  '.xdm-global-lock',
#  '.xdman',
#  '3D Objects',
#  'abc.txt',
#  'aiml face mask',
#  'Anaconda3',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'args and kwargs.ipynb',
#  'Assignment 1.ipynb',
#  'assignment 2 .ipynb',
#  'Assignment 2A.ipynb',
#  'Assignment 3.ipynb',
#  'Assignment 4.ipynb',
#  'Assignment 5.ipynb',
#  'Assignment 6.ipynb',
#  'Assignment 7.ipynb',
#  'A_T_M.ipynb',
#  'calculate the average of marks 1.ipynb',
#  'calculate the average of marks.ipynb',
#  'Calen Probs.ipynb',
#  'Cisco Packet Tracer 8.0',
#  'class 1 revision.ipynb',
#  'class 1.ipynb',
#  'class work.ipynb',
#  'Collections Module.ipynb',
#  'Contacts',
#  'Cookies',
#  'count the repeat words 1.ipynb',
#  'count the repeat words.ipynb',
#  'create audio voice.ipynb',
#  'date and time.ipynb',
#  'decorators.ipynb',
#  'defining fuction 4.ipynb',
#  'defining function 1.ipynb',
#  'defining function 10.ipynb',
#  'defining function 2.ipynb',
#  'defining function 3.ipynb',
#  'defining function 5.ipynb',
#  'defining function 6.ipynb',
#  'defining function 7.ipynb',
#  'defining function 8.ipynb',
#  'defining function 9.ipynb',
#  'Desktop',
#  'dictionary.ipynb',
#  'Documents',
#  'doochi_1.ipynb',
#  'Downloads',
#  'edureka ai face mask project',
#  'edureka-ai project day 2.ipynb',
#  'Errors and Exception Handling.ipynb',
#  'Favorites',
#  'file 1.ipynb',
#  'file 2.ipynb',
#  'find average of grades.ipynb',
#  'flag.ipynb',
#  'for loop 1.ipynb',
#  'for loop 2.ipynb',
#  'For loop.ipynb',
#  'Functions and Methods Homework.ipynb',
#  'Generators.ipynb',
#  'Greatest and Equal Between Four Number.ipynb',
#  'greatest of four digit.ipynb',
#  'Greatest of four integer.ipynb',
#  'hello world.ipynb',
#  'ho-chi-tao.ipynb',
#  'if  elif else.ipynb',
#  'if elif else 1.ipynb',
#  'IntelGraphicsProfiles',
#  'intershala ml training',
#  'lam, map and filter.ipynb',
#  'Lecture 4-Copy1.ipynb',
#  'Lecture 4.ipynb',
#  'Lecture 5.ipynb',
#  'Lecture 6.ipynb',
#  'Lecture 7.ipynb',
#  'Lecture 8.ipynb',
#  'Lecture 9.ipynb',
#  'legb rule.ipynb',
#  'Lev_1.ipynb',
#  'Lev_2.ipynb',
#  'Links',
#  'list 4.ipynb',
#  'list coprehension.ipynb',
#  'list_1.ipynb',
#  'list_2.ipynb',
#  'list_3.ipynb',
#  'Local Settings',
#  'Methods and Functions.ipynb',
#  'MicrosoftEdgeBackups',
#  'ML M4 T2 V4 Data exploration target variable 4.ipynb',
#  'Modules and Packages 1.ipynb',
#  'Music',
#  'My Documents',
#  'my exa 4.ipynb',
#  'my exa 5.ipynb',
#  'myexa copy.ipynb',
#  'myexa.ipynb',
#  'myexa2.ipynb',
#  'myexa3.ipynb',
#  'myfile_text',
#  'my_file.text',
#  'my_file.txt',
#  'nes sten & sco 1.ipynb',
#  'nes sten & sco.ipynb',
#  'NetHood',
#  'newXMLDocument.xml',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TM.blf',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Overview of geoprocessing using python',
#  'Pictures',
#  'playing card game.ipynb',
#  'PrintHood',
#  'py.py',
#  'pyth.py',
#  'python',
#  'quiz1.ipynb',
#  'quiz2.ipynb',
#  'Recent',
#  'reverse_1.ipynb',
#  'reverse_2.ipynb',
#  'reverse_3.ipynb',
#  'revision 1.ipynb',
#  'revision 2.ipynb',
#  'revision 3.ipynb',
#  'revision 4.ipynb',
#  'revision 5.ipynb',
#  'revision 6.ipynb',
#  'revision.ipynb',
#  'rough',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'set_1.ipynb',
#  'set_2.ipynb',
#  'Shutil and OS Modules.ipynb',
#  'star pattern.ipynb',
#  'Start Menu',
#  'string formating.ipynb',
#  'Templates',
#  'testfile',
#  'text_to_speech.ipynb',
#  'Tic Tac Toe game.ipynb',
#  'time pass 1.ipynb',
#  'time pass 2.ipynb',
#  'time pass 3.ipynb',
#  'time pass 4.ipynb',
#  'ttt.ipynb',
#  'tuple.ipynb',
#  'untitled0.py',
#  'untitled1.py',
#  'user defined list.ipynb',
#  'Videos',
#  'while 1.ipynb',
#  'while 2.ipynb']

# %%
shutil.move('C:\\Users\\0526p\\rough\\practice.txt', os.getcwd())
# Out:
# 'C:\\Users\\0526p\\practice.txt'

# %%
import send2trash

# %%
os.listdir()
# Out:
# [' random value is equal to guess value 1.ipynb',
#  ' random value is equal to guess value 2.ipynb',
#  ' random value is equal to guess value 3.ipynb',
#  ' random value is equal to guess value.ipynb',
#  '.anaconda',
#  '.android',
#  '.AndroidStudio3.5',
#  '.atom',
#  '.conda',
#  '.condarc',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.nbi',
#  '.packettracer',
#  '.pylint.d',
#  '.spyder-py3',
#  '.vscode',
#  '.xdm-global-lock',
#  '.xdman',
#  '3D Objects',
#  'abc.txt',
#  'aiml face mask',
#  'Anaconda3',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'args and kwargs.ipynb',
#  'Assignment 1.ipynb',
#  'assignment 2 .ipynb',
#  'Assignment 2A.ipynb',
#  'Assignment 3.ipynb',
#  'Assignment 4.ipynb',
#  'Assignment 5.ipynb',
#  'Assignment 6.ipynb',
#  'Assignment 7.ipynb',
#  'A_T_M.ipynb',
#  'calculate the average of marks 1.ipynb',
#  'calculate the average of marks.ipynb',
#  'Calen Probs.ipynb',
#  'Cisco Packet Tracer 8.0',
#  'class 1 revision.ipynb',
#  'class 1.ipynb',
#  'class work.ipynb',
#  'Collections Module.ipynb',
#  'Contacts',
#  'Cookies',
#  'count the repeat words 1.ipynb',
#  'count the repeat words.ipynb',
#  'create audio voice.ipynb',
#  'date and time.ipynb',
#  'decorators.ipynb',
#  'defining fuction 4.ipynb',
#  'defining function 1.ipynb',
#  'defining function 10.ipynb',
#  'defining function 2.ipynb',
#  'defining function 3.ipynb',
#  'defining function 5.ipynb',
#  'defining function 6.ipynb',
#  'defining function 7.ipynb',
#  'defining function 8.ipynb',
#  'defining function 9.ipynb',
#  'Desktop',
#  'dictionary.ipynb',
#  'Documents',
#  'doochi_1.ipynb',
#  'Downloads',
#  'edureka ai face mask project',
#  'edureka-ai project day 2.ipynb',
#  'Errors and Exception Handling.ipynb',
#  'Favorites',
#  'file 1.ipynb',
#  'file 2.ipynb',
#  'find average of grades.ipynb',
#  'flag.ipynb',
#  'for loop 1.ipynb',
#  'for loop 2.ipynb',
#  'For loop.ipynb',
#  'Functions and Methods Homework.ipynb',
#  'Generators.ipynb',
#  'Greatest and Equal Between Four Number.ipynb',
#  'greatest of four digit.ipynb',
#  'Greatest of four integer.ipynb',
#  'hello world.ipynb',
#  'ho-chi-tao.ipynb',
#  'if  elif else.ipynb',
#  'if elif else 1.ipynb',
#  'IntelGraphicsProfiles',
#  'intershala ml training',
#  'lam, map and filter.ipynb',
#  'Lecture 4-Copy1.ipynb',
#  'Lecture 4.ipynb',
#  'Lecture 5.ipynb',
#  'Lecture 6.ipynb',
#  'Lecture 7.ipynb',
#  'Lecture 8.ipynb',
#  'Lecture 9.ipynb',
#  'legb rule.ipynb',
#  'Lev_1.ipynb',
#  'Lev_2.ipynb',
#  'Links',
#  'list 4.ipynb',
#  'list coprehension.ipynb',
#  'list_1.ipynb',
#  'list_2.ipynb',
#  'list_3.ipynb',
#  'Local Settings',
#  'Methods and Functions.ipynb',
#  'MicrosoftEdgeBackups',
#  'ML M4 T2 V4 Data exploration target variable 4.ipynb',
#  'Modules and Packages 1.ipynb',
#  'Music',
#  'My Documents',
#  'my exa 4.ipynb',
#  'my exa 5.ipynb',
#  'myexa copy.ipynb',
#  'myexa.ipynb',
#  'myexa2.ipynb',
#  'myexa3.ipynb',
#  'myfile_text',
#  'my_file.text',
#  'my_file.txt',
#  'nes sten & sco 1.ipynb',
#  'nes sten & sco.ipynb',
#  'NetHood',
#  'newXMLDocument.xml',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TM.blf',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Overview of geoprocessing using python',
#  'Pictures',
#  'playing card game.ipynb',
#  'practice.txt',
#  'PrintHood',
#  'py.py',
#  'pyth.py',
#  'python',
#  'quiz1.ipynb',
#  'quiz2.ipynb',
#  'Recent',
#  'reverse_1.ipynb',
#  'reverse_2.ipynb',
#  'reverse_3.ipynb',
#  'revision 1.ipynb',
#  'revision 2.ipynb',
#  'revision 3.ipynb',
#  'revision 4.ipynb',
#  'revision 5.ipynb',
#  'revision 6.ipynb',
#  'revision.ipynb',
#  'rough',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'set_1.ipynb',
#  'set_2.ipynb',
#  'Shutil and OS Modules.ipynb',
#  'star pattern.ipynb',
#  'Start Menu',
#  'string formating.ipynb',
#  'Templates',
#  'testfile',
#  'text_to_speech.ipynb',
#  'Tic Tac Toe game.ipynb',
#  'time pass 1.ipynb',
#  'time pass 2.ipynb',
#  'time pass 3.ipynb',
#  'time pass 4.ipynb',
#  'ttt.ipynb',
#  'tuple.ipynb',
#  'untitled0.py',
#  'untitled1.py',
#  'user defined list.ipynb',
#  'Videos',
#  'while 1.ipynb',
#  'while 2.ipynb']

# %%
 send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# [' random value is equal to guess value 1.ipynb',
#  ' random value is equal to guess value 2.ipynb',
#  ' random value is equal to guess value 3.ipynb',
#  ' random value is equal to guess value.ipynb',
#  '.anaconda',
#  '.android',
#  '.AndroidStudio3.5',
#  '.atom',
#  '.conda',
#  '.condarc',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.nbi',
#  '.packettracer',
#  '.pylint.d',
#  '.spyder-py3',
#  '.vscode',
#  '.xdm-global-lock',
#  '.xdman',
#  '3D Objects',
#  'abc.txt',
#  'aiml face mask',
#  'Anaconda3',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'args and kwargs.ipynb',
#  'Assignment 1.ipynb',
#  'assignment 2 .ipynb',
#  'Assignment 2A.ipynb',
#  'Assignment 3.ipynb',
#  'Assignment 4.ipynb',
#  'Assignment 5.ipynb',
#  'Assignment 6.ipynb',
#  'Assignment 7.ipynb',
#  'A_T_M.ipynb',
#  'calculate the average of marks 1.ipynb',
#  'calculate the average of marks.ipynb',
#  'Calen Probs.ipynb',
#  'Cisco Packet Tracer 8.0',
#  'class 1 revision.ipynb',
#  'class 1.ipynb',
#  'class work.ipynb',
#  'Collections Module.ipynb',
#  'Contacts',
#  'Cookies',
#  'count the repeat words 1.ipynb',
#  'count the repeat words.ipynb',
#  'create audio voice.ipynb',
#  'date and time.ipynb',
#  'decorators.ipynb',
#  'defining fuction 4.ipynb',
#  'defining function 1.ipynb',
#  'defining function 10.ipynb',
#  'defining function 2.ipynb',
#  'defining function 3.ipynb',
#  'defining function 5.ipynb',
#  'defining function 6.ipynb',
#  'defining function 7.ipynb',
#  'defining function 8.ipynb',
#  'defining function 9.ipynb',
#  'Desktop',
#  'dictionary.ipynb',
#  'Documents',
#  'doochi_1.ipynb',
#  'Downloads',
#  'edureka ai face mask project',
#  'edureka-ai project day 2.ipynb',
#  'Errors and Exception Handling.ipynb',
#  'Favorites',
#  'file 1.ipynb',
#  'file 2.ipynb',
#  'find average of grades.ipynb',
#  'flag.ipynb',
#  'for loop 1.ipynb',
#  'for loop 2.ipynb',
#  'For loop.ipynb',
#  'Functions and Methods Homework.ipynb',
#  'Generators.ipynb',
#  'Greatest and Equal Between Four Number.ipynb',
#  'greatest of four digit.ipynb',
#  'Greatest of four integer.ipynb',
#  'hello world.ipynb',
#  'ho-chi-tao.ipynb',
#  'if  elif else.ipynb',
#  'if elif else 1.ipynb',
#  'IntelGraphicsProfiles',
#  'intershala ml training',
#  'lam, map and filter.ipynb',
#  'Lecture 4-Copy1.ipynb',
#  'Lecture 4.ipynb',
#  'Lecture 5.ipynb',
#  'Lecture 6.ipynb',
#  'Lecture 7.ipynb',
#  'Lecture 8.ipynb',
#  'Lecture 9.ipynb',
#  'legb rule.ipynb',
#  'Lev_1.ipynb',
#  'Lev_2.ipynb',
#  'Links',
#  'list 4.ipynb',
#  'list coprehension.ipynb',
#  'list_1.ipynb',
#  'list_2.ipynb',
#  'list_3.ipynb',
#  'Local Settings',
#  'Methods and Functions.ipynb',
#  'MicrosoftEdgeBackups',
#  'ML M4 T2 V4 Data exploration target variable 4.ipynb',
#  'Modules and Packages 1.ipynb',
#  'Music',
#  'My Documents',
#  'my exa 4.ipynb',
#  'my exa 5.ipynb',
#  'myexa copy.ipynb',
#  'myexa.ipynb',
#  'myexa2.ipynb',
#  'myexa3.ipynb',
#  'myfile_text',
#  'my_file.text',
#  'my_file.txt',
#  'nes sten & sco 1.ipynb',
#  'nes sten & sco.ipynb',
#  'NetHood',
#  'newXMLDocument.xml',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TM.blf',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{fee9e425-957d-11eb-be0b-c200d6cdb056}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Overview of geoprocessing using python',
#  'Pictures',
#  'playing card game.ipynb',
#  'PrintHood',
#  'py.py',
#  'pyth.py',
#  'python',
#  'quiz1.ipynb',
#  'quiz2.ipynb',
#  'Recent',
#  'reverse_1.ipynb',
#  'reverse_2.ipynb',
#  'reverse_3.ipynb',
#  'revision 1.ipynb',
#  'revision 2.ipynb',
#  'revision 3.ipynb',
#  'revision 4.ipynb',
#  'revision 5.ipynb',
#  'revision 6.ipynb',
#  'revision.ipynb',
#  'rough',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'set_1.ipynb',
#  'set_2.ipynb',
#  'Shutil and OS Modules.ipynb',
#  'star pattern.ipynb',
#  'Start Menu',
#  'string formating.ipynb',
#  'Templates',
#  'testfile',
#  'text_to_speech.ipynb',
#  'Tic Tac Toe game.ipynb',
#  'time pass 1.ipynb',
#  'time pass 2.ipynb',
#  'time pass 3.ipynb',
#  'time pass 4.ipynb',
#  'ttt.ipynb',
#  'tuple.ipynb',
#  'untitled0.py',
#  'untitled1.py',
#  'user defined list.ipynb',
#  'Videos',
#  'while 1.ipynb',
#  'while 2.ipynb']

# %%
file_path = 'C:\\Users\\0526p\\intershala ml training'

# %%
for folder, sub_folders, files in os.walk(file_path):
    print(f"Currently looking at {folder}")
    print('\n')
    print('The subfolders are : ')
    for sub_fold in sub_folders:
        print(f"\t Subfolder: {sub_fold}")
        
    print('\n')
    print('the files are :')
    for f in files:
        print(f"\t File : {f}")
        
    print('\n')
# Out:
# Currently looking at C:\Users\0526p\intershala ml training
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
# 	 Subfolder: assignment 10
# 	 Subfolder: assignment 4
# 	 Subfolder: assignment 5
# 	 Subfolder: assignment 6
# 	 Subfolder: assignment 7
# 	 Subfolder: assignment 8
# 	 Subfolder: assignment 9
# 	 Subfolder: ML M10
# 	 Subfolder: ML M3
# 	 Subfolder: ML M4
# 	 Subfolder: ML M5
# 	 Subfolder: ML M6
# 	 Subfolder: ML M7
# 	 Subfolder: ML M8
# 	 Subfolder: ML M9
#
#
# the files are :
# 	 File : housing data
# 	 File : Untitled.ipynb
# 	 File : USA_Housing.csv
#
#
# Currently looking at C:\Users\0526p\intershala ml training\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : Untitled-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 10
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : clustering.csv
# 	 File : M10_T1 Exercise.ipynb
# 	 File : M10_T1 istructor solution.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 10\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : M10_T1 Exercise-checkpoint.ipynb
# 	 File : M10_T1 istructor solution-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 4
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : assignment 4 instructor solution.ipynb
# 	 File : assignment 4 solution.ipynb
# 	 File : assignment 4.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 4\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : assignment 4 instructor solution-checkpoint.ipynb
# 	 File : assignment 4-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 5
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : assignment 5 instructor solutions.ipynb
# 	 File : assignment 5 my solutions.ipynb
# 	 File : assignment 5.ipynb
# 	 File : Transformed_Housing_Data2.csv
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 5\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : assignment 5 instructor solutions-checkpoint.ipynb
# 	 File : assignment 5 my solutions-checkpoint.ipynb
# 	 File : assignment 5-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 6
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : assignment 6 my solution.ipynb
# 	 File : Forward selection bug.ipynb
# 	 File : Forward selection instructor solution.ipynb.ipynb
# 	 File : Transformed_Housing_Data2.csv
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 6\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : assignment 6 my solution-checkpoint.ipynb
# 	 File : Forward selection bug-checkpoint.ipynb
# 	 File : Forward selection instructor solution.ipynb-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 7
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : m7t2 exercise my solution.ipynb
# 	 File : m7t2 exercise.ipynb
# 	 File : m7t2 instructor solution.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 7\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : m7t2 exercise my solution-checkpoint.ipynb
# 	 File : m7t2 exercise-checkpoint.ipynb
# 	 File : m7t2 instructor solution-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 8
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : A_Churn_Prediction instructor solution.ipynb
# 	 File : churn_prediction.csv
# 	 File : Q_Churn_Prediction my solution.ipynb
# 	 File : Q_Churn_Prediction.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 8\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : A_Churn_Prediction instructor solution-checkpoint.ipynb
# 	 File : Q_Churn_Prediction my solution-checkpoint.ipynb
# 	 File : Q_Churn_Prediction-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 9
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : churn_prediction_simple.csv
# 	 File : M9_T1 instructor solution.ipynb
# 	 File : M9_T1 my solution.ipynb
# 	 File : M9_T1.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\assignment 9\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : M9_T1 instructor solution-checkpoint.ipynb
# 	 File : M9_T1 my solution-checkpoint.ipynb
# 	 File : M9_T1-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M10
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : ML M10 T3 V1 Implementation of k-means 1.ipynb
# 	 File : ML M10 T3 V2 Implementation of k-means 2.ipynb
# 	 File : Population_Data.csv
# 	 File : Topic3.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M10\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : ML M10 T3 V1 Implementation of k-means 1-checkpoint.ipynb
# 	 File : ML M10 T3 V2 Implementation of k-means 2-checkpoint.ipynb
# 	 File : Topic3-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M3
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : ML M3 T2 V1 Data Types.ipynb
# 	 File : ML M3 T2 V2 Basic Arithmetic Operations.ipynb
# 	 File : ML M3 T2 V4 Basic Libraries.ipynb
# 	 File : ML M3 T3 V3 Functions.ipynb
# 	 File : ML M3 T4 V1 Interpretation of Imported Data_1.ipynb
# 	 File : ML M3 T4 V2 Desciptive Statistics part 1.ipynb
# 	 File : ML M3 T4 V3 Descriptives Statistics part 2.ipynb
# 	 File : ML M3 T4 V4 Plotting Graphs part 1.ipynb
# 	 File : ML M3 T4 V5 Plotting Graphs part 2.ipynb
# 	 File : ML M3 T5 V1 pandas.groupby().ipynb
# 	 File : ML M3 T5 V2 pandas.pivot_table().ipynb
# 	 File : ML M3 T5 V3 pandas.map().ipynb
# 	 File : ML M3 T5 V4 pandas.apply().ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M3\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : ML M3 T2 V1 Data Types-checkpoint.ipynb
# 	 File : ML M3 T2 V2 Basic Arithmetic Operations-checkpoint.ipynb
# 	 File : ML M3 T2 V4 Basic Libraries-checkpoint.ipynb
# 	 File : ML M3 T3 V3 Functions-checkpoint.ipynb
# 	 File : ML M3 T4 V1 Interpretation of Imported Data_1-checkpoint.ipynb
# 	 File : ML M3 T4 V2 Desciptive Statistics part 1-checkpoint.ipynb
# 	 File : ML M3 T4 V3 Descriptives Statistics part 2-checkpoint.ipynb
# 	 File : ML M3 T4 V4 Plotting Graphs part 1-checkpoint.ipynb
# 	 File : ML M3 T4 V5 Plotting Graphs part 2-checkpoint.ipynb
# 	 File : ML M3 T5 V1 pandas.groupby()-checkpoint.ipynb
# 	 File : ML M3 T5 V2 pandas.pivot_table()-checkpoint.ipynb
# 	 File : ML M3 T5 V3 pandas.map()-checkpoint.ipynb
# 	 File : ML M3 T5 V4 pandas.apply()-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M4
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : 1. Regression - Module - (Housing Prices).csv
# 	 File : ML M4 T2 V1 Data exploration target variable 1.ipynb
# 	 File : ML M4 T2 V2 Data exploration target variable 2.ipynb
# 	 File : ML M4 T2 V3 Data exploration target variable 3.ipynb
# 	 File : ML M4 T2 V4 Data exploration target variable 4.ipynb
# 	 File : ML M4 T3 V0 Data exploration independent variables 1.ipynb
# 	 File : ML M4 T3 V1 Data exploration independent variables 2.ipynb
# 	 File : ML M4 T3 V2 Correlation.ipynb
# 	 File : ML M4 T4 V1 Data exploration categorical variables.ipynb
# 	 File : ML M4 T4 V2 ANOVA.ipynb
# 	 File : ML M4 T4 V3 Creation of dummy variables.ipynb
# 	 File : ML M4 T5 V1 Splitting of data.ipynb
# 	 File : ML M4 T6 V1 Feature scaling.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M4\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : ML M4 T2 V1 Data exploration target variable 1-checkpoint.ipynb
# 	 File : ML M4 T2 V2 Data exploration target variable 2-checkpoint.ipynb
# 	 File : ML M4 T2 V3 Data exploration target variable 3-checkpoint.ipynb
# 	 File : ML M4 T2 V4 Data exploration target variable 4-checkpoint.ipynb
# 	 File : ML M4 T3 V0 Data exploration independent variables 1-checkpoint.ipynb
# 	 File : ML M4 T3 V1 Data exploration independent variables 2-checkpoint.ipynb
# 	 File : ML M4 T3 V2 Correlation-checkpoint.ipynb
# 	 File : ML M4 T4 V1 Data exploration categorical variables-checkpoint.ipynb
# 	 File : ML M4 T4 V2 ANOVA-checkpoint.ipynb
# 	 File : ML M4 T4 V3 Creation of dummy variables-checkpoint.ipynb
# 	 File : ML M4 T5 V1 Splitting of data-checkpoint.ipynb
# 	 File : ML M4 T6 V1 Feature scaling-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M5
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : 1. Regression - Module - (Housing Prices).csv
# 	 File : ML M5 T1 V1 Building your first predictive model(Regression).ipynb
# 	 File : ML M5 T1 V2 Improving upon the mean regression model.ipynb
# 	 File : ML M5 T1 V3 Residual Plots.ipynb
# 	 File : ML M5 T1 V4 Model evalution metrics 1.ipynb
# 	 File : ML M5 T1 V5 Model evalution metrics 2.ipynb
# 	 File : ML M5 T2 V1 What is linear regression.ipynb
# 	 File : ML M5 T2 V3 Cost function curve.ipynb
# 	 File : ML M5 T2 V4 Parameters of the linear regression 2.ipynb
# 	 File : ML M5 T3 V3 Implementing gradient descent.ipynb
# 	 File : ML M5 T5 V1 Treating multicollinearity 1.ipynb
# 	 File : ML M5 T5 V2 Treating multicollinearity 2.ipynb
# 	 File : ML M5 T5 V3 Training the model.ipynb
# 	 File : ML M5 T5 V4 Verify the assumptions of linear regression model.ipynb
# 	 File : ML M5 T5 V5 Interpreting the results.ipynb
# 	 File : ML M5 T6 V1 Feature Engineering.ipynb
# 	 File : ML M5 T6 V2 Feature Preprocessing.ipynb
# 	 File : ML M5 T6 V3 Feature transformation (categorical encoding).ipynb
# 	 File : ML M5 T6 V4 Feature transformation (binning).ipynb
# 	 File : ML M5 T6 V5 Feature generation.ipynb
# 	 File : Raw_Housing_Prices3.csv
# 	 File : Transformed_Housing_Data2.csv
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M5\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : ML M5 T1 V1 Building your first predictive model(Regression)-checkpoint.ipynb
# 	 File : ML M5 T1 V2 Improving upon the mean regression model-checkpoint.ipynb
# 	 File : ML M5 T1 V3 Residual Plots-checkpoint.ipynb
# 	 File : ML M5 T1 V4 Model evalution metrics 1-checkpoint.ipynb
# 	 File : ML M5 T1 V5 Model evalution metrics 2-checkpoint.ipynb
# 	 File : ML M5 T2 V1 What is linear regression-checkpoint.ipynb
# 	 File : ML M5 T2 V3 Cost function curve-checkpoint.ipynb
# 	 File : ML M5 T2 V4 Parameters of the linear regression 2-checkpoint.ipynb
# 	 File : ML M5 T3 V3 Implementing gradient descent-checkpoint.ipynb
# 	 File : ML M5 T5 V1 Treating multicollinearity 1-checkpoint.ipynb
# 	 File : ML M5 T5 V2 Treating multicollinearity 2-checkpoint.ipynb
# 	 File : ML M5 T5 V3 Training the model-checkpoint.ipynb
# 	 File : ML M5 T5 V4 Verify the assumptions of linear regression model-checkpoint.ipynb
# 	 File : ML M5 T5 V5 Interpreting the results-checkpoint.ipynb
# 	 File : ML M5 T6 V1 Feature Engineering-checkpoint.ipynb
# 	 File : ML M5 T6 V2 Feature Preprocessing-checkpoint.ipynb
# 	 File : ML M5 T6 V3 Feature transformation (categorical encoding)-checkpoint.ipynb
# 	 File : ML M5 T6 V4 Feature transformation (binning)-checkpoint.ipynb
# 	 File : ML M5 T6 V5 Feature generation-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M6
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : Backward_Forward selection.ipynb
# 	 File : ML M6 T1 V2 Common dimensionality reduction techniques 2.ipynb
# 	 File : ML M6 T1 V3 Common dimensionality reduction techniques 3.ipynb
# 	 File : ML M6 T2 V1 Advanced dimensionality reduction techniques 1.ipynb
# 	 File : ML M6 T2 V2 Advanced dimensionality reduction techniques 2.ipynb
# 	 File : ML M6 T2 V3 Advanced dimensionality reduction techniques 3.ipynb
# 	 File : NaN_Housing_Prices.csv
# 	 File : Raw_Housing_Prices.csv
# 	 File : Raw_Housing_Prices3.csv
# 	 File : Topic 1.ipynb
# 	 File : Transformed_Housing_Data2.csv
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M6\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : Backward_Forward selection-checkpoint.ipynb
# 	 File : ML M6 T1 V2 Common dimensionality reduction techniques 2-checkpoint.ipynb
# 	 File : ML M6 T1 V3 Common dimensionality reduction techniques 3-checkpoint.ipynb
# 	 File : ML M6 T2 V1 Advanced dimensionality reduction techniques 1-checkpoint.ipynb
# 	 File : ML M6 T2 V2 Advanced dimensionality reduction techniques 2-checkpoint.ipynb
# 	 File : ML M6 T2 V3 Advanced dimensionality reduction techniques 3-checkpoint.ipynb
# 	 File : Topic 1-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M7
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : churn_prediction_simple.csv
# 	 File : ML M7 T3 V1 Implementing logistic regression 1.ipynb
# 	 File : ML M7 T3 V2 Implementing logistic regression 2.ipynb
# 	 File : ML M7 T3 V3 Implementing logistic regression 3.ipynb
# 	 File : Topic3.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M7\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : ML M7 T3 V1 Implementing logistic regression 1-checkpoint.ipynb
# 	 File : ML M7 T3 V2 Implementing logistic regression 2-checkpoint.ipynb
# 	 File : ML M7 T3 V3 Implementing logistic regression 3-checkpoint.ipynb
# 	 File : Topic3-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M8
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : churn_prediction_simple.csv
# 	 File : free_viz
# 	 File : free_viz.png
# 	 File : ML M8 T3 V1 Implementing decision tree 1.ipynb
# 	 File : ML M8 T3 V2 Implementing decision tree 2.ipynb
# 	 File : ML M8 T4 V1 Improving model performance by prunning_hyperparameters testing 1.ipynb
# 	 File : ML M8 T4 V2 Feature importance 2.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M8\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : ML M8 T3 V1 Implementing decision tree 1-checkpoint.ipynb
# 	 File : ML M8 T3 V2 Implementing decision tree 2-checkpoint.ipynb
# 	 File : ML M8 T4 V1 Improving model performance by prunning_hyperparameters testing 1-checkpoint.ipynb
# 	 File : ML M8 T4 V2 Feature importance 2-checkpoint.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M9
#
#
# The subfolders are :
# 	 Subfolder: .ipynb_checkpoints
#
#
# the files are :
# 	 File : churn_prediction_simple.csv
# 	 File : ML M9 T3 V1 Implementation of bagging and random forest.ipynb
# 	 File : ML M9 T3 V2 Hyperparameter tuning in random forest.ipynb
#
#
# Currently looking at C:\Users\0526p\intershala ml training\ML M9\.ipynb_checkpoints
#
#
# The subfolders are :
#
#
# the files are :
# 	 File : ML M9 T3 V1 Implementation of bagging and random forest-checkpoint.ipynb
# 	 File : ML M9 T3 V2 Hyperparameter tuning in random forest-checkpoint.ipynb
