# %%
x=-45
while x<45:
    print(f"current value of x = {x}")
    x=x+1
# Out:
# current value of x = -45
# current value of x = -44
# current value of x = -43
# current value of x = -42
# current value of x = -41
# current value of x = -40
# current value of x = -39
# current value of x = -38
# current value of x = -37
# current value of x = -36
# current value of x = -35
# current value of x = -34
# current value of x = -33
# current value of x = -32
# current value of x = -31
# current value of x = -30
# current value of x = -29
# current value of x = -28
# current value of x = -27
# current value of x = -26
# current value of x = -25
# current value of x = -24
# current value of x = -23
# current value of x = -22
# current value of x = -21
# current value of x = -20
# current value of x = -19
# current value of x = -18
# current value of x = -17
# current value of x = -16
# current value of x = -15
# current value of x = -14
# current value of x = -13
# current value of x = -12
# current value of x = -11
# current value of x = -10
# current value of x = -9
# ...
